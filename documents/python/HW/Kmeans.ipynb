# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from scipy.spatial.distance import cdist

# %%
x = 20
x1 = np.random.random(45)*20
x1 = x-x1
y = 20
y1 = np.random.random(45)*20
y1 = y-y1


x2 = 80
x3 = np.random.random(45)*20
x3 = x2-x3
y2 = 30
y3 = np.random.random(45)*20
y3 = y2-y3

x4 = 30
x5 = np.random.random(45)*20
x5 = x4-x5
y4 = 80
y5 = np.random.random(45)*20
y5 = y4-y5

# %%
plt.scatter(x1,y1)
plt.scatter(x3,y3)
plt.scatter(x5,y5)

# %%
beta1 = [2,3]
beta2 = [20,30]
beta3 = [13,27]

# %%
plt.scatter(x1,y1)
plt.scatter(x3,y3)
plt.scatter(x5,y5)
plt.scatter(beta1[0],beta1[1],linewidths=10)
plt.scatter(beta2[0],beta2[1],linewidths=10)
plt.scatter(beta3[0],beta3[1],linewidths=10)

# %%
Xarr = np.concatenate((x1,x3,x5))
Yarr = np.concatenate((y1,y3,y5))
XYarr = np.concatenate((Xarr,Yarr))
BetaArr = np.concatenate((beta1,beta2,beta3))

# %%
XYarr = XYarr.reshape(135,2)
BetaArr=BetaArr.reshape(3,2)
SomeArr = []

# %%
for i in range(1000):
    SomeArr.append(sum(np.min(cdist(XYarr, BetaArr), axis=1)) / XYarr.shape[0])

# %%
from sklearn.datasets.samples_generator import make_blobs
centers = np.array([[2, 2], [8, 9], [9, 5], [3,9]])
Xarray, ysome = make_blobs(n_samples=200, n_features=2, centers=centers, cluster_std=0.5, center_box=(1, 10.0), shuffle=True, random_state=0)
c1=[]
c2=[]
c3=[]
c4=[]

# %%
iterations = 100

# %%
from sklearn.datasets.samples_generator import make_blobs
centers = np.array([[2, 2], [8, 9], [9, 5], [3,9]])
Xarray, ysome = make_blobs(n_samples=200, n_features=2, centers=centers, cluster_std=0.5, center_box=(1, 10.0), shuffle=True, random_state=0)

# %%
plt.scatter(Xarray[:,0],Xarray[:,1],cmap = 'rainbow')
plt.scatter(centers[:,0],centers[:,1],cmap = 'rainbow')

# %%
centroids = np.array([[5,5],[6,5],[6,6],[5,6]])

plt.scatter(centroids[:,0],centroids[:,1],marker="*",c="gold")
plt.scatter(Xarray[:,0],Xarray[:,1],cmap = 'rainbow')

# %%
for i in range(iterations):
    c1=[]
    c2=[]
    c3=[]
    c4=[]
    distdf = pd.DataFrame(cdist(Xarray,centroids))
    shoot = distdf.idxmin(axis=1)
    for i in range(len(shoot)):
        if shoot[i] ==0:
            c1.append(Xarray[i])
        elif shoot[i] ==1:
            c2.append(Xarray[i])
        elif shoot[i]==2:
            c3.append(Xarray[i])
        elif shoot[i]==3:
            c4.append(Xarray[i])
        
    c1 = pd.DataFrame(c1)
    c2 = pd.DataFrame(c2)
    c3 = pd.DataFrame(c3)
    c4 = pd.DataFrame(c4)
    centre = np.array([[(c1[0].sum())/len(c1),(c1[1].sum())/len(c1)],[(c2[0].sum())/len(c2),(c2[1].sum())/len(c2)],[(c3[0].sum())/len(c3),(c3[1].sum())/len(c3)],[(c4[0].sum())/len(c4),(c4[1].sum())/len(c4)]])
    centroids = centre
    plt.scatter(Xarray[:,0],Xarray[:,1],cmap ='rainbow')
    plt.scatter(centroids[:,0],centroids[:,1],marker="*",c="gold")
    plt.pause(0.05)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-e7ca15cf6afe> in <module>
#      17
#      18     c1 = pd.DataFrame(c1)
# ---> 19     c2 = pd.DataFrame(c2)
#      20     c3 = pd.DataFrame(c3)
#      21     c4 = pd.DataFrame(c4)
#
# c:\users\chirag nagpal\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     398
#     399                     mgr = _arrays_to_mgr(arrays, columns, index, columns,
# --> 400                                          dtype=dtype)
#     401                 else:
#     402                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
#
# c:\users\chirag nagpal\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
# ...

# %%
Xarray
# Out:
# array([[ 3.13487731,  1.27281716],
#        [ 3.13725818,  8.55454246],
#        [ 2.03325861,  2.15123595],
#        [ 7.38728224,  9.42218149],
#        [ 7.59829517,  8.65522511],
#        [ 2.47504421,  1.9243214 ],
#        [ 1.1468649 ,  2.9753877 ],
#        [ 2.81765323,  9.07835193],
#        [ 3.01931528,  8.17164245],
#        [ 2.76638961,  2.73467938],
#        [ 9.34490908,  5.65092311],
#        [ 2.42132237,  8.84385387],
#        [ 8.93202515,  5.56844568],
#        [ 7.61504196,  9.2696246 ],
#        [10.15195835,  4.46999209],
#        [ 2.15094709,  9.19364024],
#        [ 1.46462369,  2.52722586],
#        [ 2.6738532 ,  8.73940534],
#        [ 7.95077374,  8.66826086],
#        [ 3.5342547 ,  8.7733071 ],
#        [ 9.04886248,  5.29147684],
#        [ 8.47362598,  8.92249495],
#        [ 8.93377948,  9.45302233],
#        [ 8.84549352,  4.1619981 ],
#        [ 9.14317184,  5.30442192],
#        [ 7.78242322,  9.92463186],
#        [ 7.6302185 ,  9.7715073 ],
# ...

# %%
distdf
# Out:
#              0          1         2         3
# 0     0.930494   1.758918  1.533728  7.273691
# 1     7.016859   6.565398  5.975938  3.591904
# 2     0.603294   0.413441  0.602624  7.165254
# 3     9.358442   9.268236  8.427316  1.924120
# 4     8.852496   8.822572  7.957697  1.398825
# 5     0.394747   0.888664  0.702186  7.073774
# 6     1.775816   0.936862  1.309229  7.200730
# 7     7.506412   7.014490  6.468061  4.054570
# 8     6.622590   6.165663  5.581948  3.632823
# 9     1.248877   1.279215  0.375438  6.250758
# 10    8.163998   8.474155  7.568967  3.388513
# 11    7.253021   6.724911  6.220583  4.358537
# 12    7.765892   8.064426  7.158123  3.120425
# 13    9.359581   9.294552  8.443257  1.894983
# 14    8.399144   8.837245  7.961245  4.762020
# 15    7.601834   7.046821  6.575376  4.721129
# 16    1.227937   0.392496  0.948113  7.271530
# 17    7.158713   6.656498  6.121901  4.087251
# 18    9.079524   9.074454  8.201563  1.673219
# ...

# %%
shoot
# Out:
# 0      0
# 1      3
# 2      0
# 3      2
# 4      2
# 5      0
# 6      0
# 7      3
# 8      3
# 9      0
# 10     1
# 11     3
# 12     1
# 13     2
# 14     1
# 15     3
# 16     0
# 17     3
# 18     2
# 19     3
# 20     1
# 21     2
# 22     2
# 23     1
# 24     1
# 25     2
# 26     2
# 27     2
# 28     0
# 29     0
#       ..
# 170    0
# 171    1
# 172    3
# 173    1
# 174    0
# 175    3
# 176    2
# 177    0
# 178    2
# 179    3
# 180    3
# 181    1
# 182    2
# 183    1
# 184    2
# 185    3
# 186    1
# 187    3
# 188    1
# 189    0
# 190    0
# 191    0
# 192    0
# 193    1
# 194    3
# 195    3
# 196    0
# 197    1
# 198    0
# 199    1
# Length: 200, dtype: int64

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [1, 0],
               [4, 2], [4, 4], [4, 0]])
kmeans = KMeans(n_clusters=2, random_state=0)

# %%
from sklearn.datasets.samples_generator import make_blobs
centers = [[2, 2], [8, 9], [9, 5], [3,9]]
X, y =make_blobs(n_samples=200, n_features=2, centers=centers, cluster_std=0.5, center_box=(1, 10.0), shuffle=True, random_state=0)

plt.scatter(X[:, 0], X[:, 1],cmap='rainbow')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[7.99063924, 9.09137373],
#        [2.00840308, 2.05140493],
#        [2.90345829, 8.89974501],
#        [8.95346338, 4.98730436]])

# %%
print(kmeans.labels_)
# Out:
# [1 2 1 0 0 1 1 2 2 1 3 2 3 0 3 2 1 2 0 2 3 0 0 3 3 0 0 0 1 1 0 0 3 0 3 2 3
#  2 2 1 1 0 1 3 3 3 2 3 1 0 3 1 3 1 3 3 2 2 1 3 3 2 3 0 2 1 0 3 1 2 2 3 3 2
#  3 1 2 0 1 1 2 0 0 2 2 2 1 0 0 1 2 0 3 0 1 2 1 3 1 0 1 1 0 1 2 0 2 3 1 2 0
#  2 2 2 3 2 0 1 2 3 3 0 3 2 0 0 3 1 0 0 0 1 0 3 2 1 3 0 1 2 0 0 0 2 3 2 1 0
#  0 3 0 1 3 2 1 1 3 2 3 0 1 0 1 3 3 2 1 2 0 0 1 3 2 3 1 2 0 1 0 2 2 3 0 3 0
#  2 3 2 3 1 1 1 1 3 2 2 1 3 1 3]

# %%
fig, (ax1,ax2) =  plt.subplots(1,2,sharey= True , figsize= (10,6))
ax1.set_title('K Means')
ax1.scatter(X[:,0],X[:,1],c = kmeans.labels_,cmap = 'rainbow')
ax2.set_title('Orignal')
ax2.scatter(X[:,0],X[:,1],c = y,cmap = 'rainbow')

# %%
distortions = []
k = range(1,10)
for iterator in k:
    kmeans = KMeans(n_clusters = iterator).fit(X)
    distortions.append(sum(np.min(cdist(X, kmeans.cluster_centers_), axis=1)) / X.shape[0])

# %%
plt.plot(k, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import numpy as np

X = np.array([[1, 2],
              [1.5, 1.8],
              [5, 8 ],
              [8, 8],
              [1, 0.6],
              [9,11],
              [1,3],
              [8,9],
              [0,3],
              [5,4],
              [6,4],])

##plt.scatter(X[:,0], X[:,1], s=150)
##plt.show()

colors = 10*["g","r","c","b","k"]


class K_Means:
    def __init__(self, k=2, tol=0.001, max_iter=300):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):

        self.centroids = {}

        for i in range(self.k):
            self.centroids[i] = data[i]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
                    print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification


clf = K_Means()
clf.fit(X)

for centroid in clf.centroids:
    plt.scatter(clf.centroids[centroid][0], clf.centroids[centroid][1],
                marker="o", color="k", s=150, linewidths=5)

for classification in clf.classifications:
    color = colors[classification]
    for featureset in clf.classifications[classification]:
        plt.scatter(featureset[0], featureset[1], marker="x", color=color, s=150, linewidths=5)


plt.show()
# Out:
# 484.7222222222223
# 13.0
# 52.10727969348656

# %%
(Z,X,Y)

# %%
a = np.random.random([200,2])

# %%
c = np.array([[1,3],[2,5],[6,7],[8,9]]).reshape(4,1,2)

# %%
c
# Out:
# array([[[1, 3]],
#
#        [[2, 5]],
#
#        [[6, 7]],
#
#        [[8, 9]]])

# %%
# c1.append(np.sqrt((np.square(a[:,0]-c[:,0])+np.square(a[:,1]-c[:,1]))))
# Out:
# (4, 2)

# %%
# abc = ((a[:,0]- c[0,0])**2+ (a[:,1]-c[0,1])**2)**1/2

# %%
# bcd =
# Out:
# (200,)

# %%
# Out:
# (200, 4)

# %%
iterations = 10

# %%
from sklearn.datasets.samples_generator import make_blobs
centers = np.array([[2, 2], [8, 9], [9, 5], [3,9]])
Xarray, ysome = make_blobs(n_samples=200, n_features=2, centers=centers, cluster_std=0.5, center_box=(1, 10.0), shuffle=True, random_state=0)

# %%
cent =np.array([[5,5],[6,5],[6,6],[5,6]])
plt.scatter(Xarray[:,0],Xarray[:,1],cmap ='rainbow')
plt.scatter(cent[:,0],cent[:,1],marker="*",c = "gold",s = 140)

# %%
for i in range(iterations):
    cent = cent.reshape(4,1,2)
    distdf = pd.DataFrame(np.sqrt(np.sum(np.square(Xarray-cent),axis = 2)).T)
    shoot = distdf.idxmin(axis=1)
    one = pd.get_dummies(shoot)
    dotproduct = (np.dot(one.T,Xarray)).reshape(4,1,2)
    something = np.array(one[one ==1].sum()).reshape(4,1,1)
    cent = (dotproduct/something).reshape(4,2)
    plt.scatter(Xarray[:,0],Xarray[:,1],c ='red')
    plt.scatter(cent[:,0],cent[:,1],marker="*",c="gold",s=140)
    
plt.show()

# %%
cent = cent.reshape(4,1,2)
distdf = pd.DataFrame(np.sqrt(np.sum(np.square(Xarray-cent),axis = 2)).T)
shoot = distdf.idxmin(axis=1)

# %%
one = pd.get_dummies(shoot)
something = one[one==1].sum()

# %%
arrtemp = np.dot(one.T,Xarray)

# %%
something = np.array(something).reshape(4,1,1)
something
# Out:
# array([[[50.]],
#
#        [[43.]],
#
#        [[57.]],
#
#        [[50.]]])

# %%
arrtemp = arrtemp.reshape(4,1,2)
arrtemp = arrtemp/something
arrtemp
# Out:
# array([[[2.00840308, 2.05140493]],
#
#        [[8.97114728, 4.87651037]],
#
#        [[8.09554031, 8.67094664]],
#
#        [[2.90345829, 8.89974501]]])

# %%
centers = arrtemp.reshape(4,2)

# %%
centers
# Out:
# array([[2.00840308, 2.05140493],
#        [8.97114728, 4.87651037],
#        [8.09554031, 8.67094664],
#        [2.90345829, 8.89974501]])
